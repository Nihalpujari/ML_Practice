# %%
from transformers import pipeline

translator = pipeline(
    task="translation_en_to_fr",
    model="Helsinki-NLP/opus-mt-en-fr"
)

review = "The hotel was clean and the staff were very friendly."

translation = translator(review)

print(translation)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 3
#       1 from transformers import pipeline
# ----> 3 translator = pipeline(
#       4     task="translation_en_to_fr",
#       5     model="Helsinki-NLP/opus-mt-en-fr"
#       6 )
#       8 review = "The hotel was clean and the staff were very friendly."
#      10 translation = translator(review)
#
# File d:\nihal\New folder\Lib\site-packages\transformers\pipelines\__init__.py:944, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     937         pipeline_class = get_class_from_dynamic_module(
#     938             class_ref,
#     939             model,
#     940             code_revision=code_revision,
#     941             **hub_kwargs,
#     942         )
#     943 else:
# --> 944     normalized_task, targeted_task, task_options = check_task(task)
#     945     if pipeline_class is None:
#     946         pipeline_class = targeted_task["impl"]
#
# File d:\nihal\New folder\Lib\site-packages\transformers\pipelines\__init__.py:356, in check_task(task)
#     320 def check_task(task: str) -> tuple[str, dict, Any]:
#     321     """
#     322     Checks an incoming task string, to validate it's correct and return the default Pipeline and Model classes, and
#     323     default models if they exist.
#    (...)
#     354
#     355     """
# --> 356     return PIPELINE_REGISTRY.check_task(task)
#
# File d:\nihal\New folder\Lib\site-packages\transformers\pipelines\base.py:1340, in PipelineRegistry.check_task(self, task)
#    1337     targeted_task = self.supported_tasks[task]
#    1338     return task, targeted_task, None
# -> 1340 raise KeyError(f"Unknown task {task}, available tasks are {self.get_supported_tasks()}")
#
# KeyError: "Unknown task translation_en_to_fr, available tasks are ['any-to-any', 'audio-classification', 'automatic-speech-recognition', 'depth-estimation', 'document-question-answering', 'feature-extraction', 'fill-mask', 'image-classification', 'image-feature-extraction', 'image-segmentation', 'image-text-to-text', 'keypoint-matching', 'mask-generation', 'ner', 'object-detection', 'sentiment-analysis', 'table-question-answering', 'text-classification', 'text-generation', 'text-to-audio', 'text-to-speech', 'token-classification', 'video-classification', 'zero-shot-audio-classification', 'zero-shot-classification', 'zero-shot-image-classification', 'zero-shot-object-detection']"

# %%
import transformers
print(transformers.__version__)
# Out:
# 5.10.2
