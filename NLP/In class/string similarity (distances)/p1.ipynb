# %%
from scipy.spatial import distance
string1='test'
string2='text'
hamming_distance=distance.hamming(list(string1),list(string2))
print(hamming_distance)
# Out:
# 0.25

# %%
import Levenshtein
word1="kitten"
word2="sitting"
distance=Levenshtein.distance(word1,word2)
distance
# Out:
# 3
