# %%
text = """
Natural Language Processing, also known as NLP, is one of the most important areas of Artificial Intelligence.
Today, companies use NLP in chatbots, search engines, recommendation systems, social media analytics,
customer feedback analysis, automatic translation, and voice assistants.
 
In 2026, many organizations are collecting huge amounts of text data from websites, emails, reviews,
online forms, tweets, product comments, and support tickets. However, this text data is often messy.
For example, a customer may write: "I LOVE this product!!! Visit https://example.com/product123 #Amazing #AI".
Another user may write: "The service was not good... I waited 45 minutes and no one replied."
 
Before applying machine learning or deep learning models, we need to clean and prepare the text.
This step is called text preprocessing. It may include converting text to lowercase, removing URLs,
removing punctuation, removing numbers, tokenizing sentences into words, removing stop words,
stemming, lemmatization, and sometimes removing emojis or special characters.
 
Good preprocessing can improve the quality of NLP models. However, preprocessing should be done carefully.
For example, removing the word "not" from the sentence "I am not happy" can change the meaning completely.
Similarly, removing hashtags may not always be a good idea in social media analytics because hashtags
can contain useful information about topics, opinions, or trends.
 
Your task is to build a complete NLP preprocessing pipeline for this text.
You should clean the text step by step and observe how the output changes after each step.
"""

# %% [markdown]
# removing hashtags

# %%
import re
rep_hash=re.sub(r'#[\w]+','',text)

def to_lower(match):
    word = match.group()
    if re.match(r'[A-Z]{2,}', word):  
        return word.lower()
    else:
        return word

lowered = re.sub(r'\b[A-Z]+\b', to_lower, rep_hash)
print(lowered)
# Out:
# Natural Language Processing, also known as nlp, is one of the most important areas of Artificial Intelligence.
# Today, companies use nlp in chatbots, search engines, recommendation systems, social media analytics,
# customer feedback analysis, automatic translation, and voice assistants.
#
# In 2026, many organizations are collecting huge amounts of text data from websites, emails, reviews,
# online forms, tweets, product comments, and support tickets. However, this text data is often messy.
# For example, a customer may write: "I love this product!!! Visit https://example.com/product123  ".
# Another user may write: "The service was not good... I waited 45 minutes and no one replied."
#
# Before applying machine learning or deep learning models, we need to clean and prepare the text.
# This step is called text preprocessing. It may include converting text to lowercase, removing URLs,
# removing punctuation, removing numbers, tokenizing sentences into words, removing stop words,
# stemming, lemmatization, and sometimes removing emojis or special characters.
#
# Good preprocessing can improve the quality of nlp models. However, preprocessing should be done carefully.
# For example, removing the word "not" from the sentence "I am not happy" can change the meaning completely.
# Similarly, removing hashtags may not always be a good idea in social media analytics because hashtags
# can contain useful information about topics, opinions, or trends.
#
# Your task is to build a complete nlp preprocessing pipeline for this text.
# You should clean the text step by step and observe how the output changes after each step.

# %%
import nltk
import string

# %%
words = nltk.word_tokenize(rep_hash)
print(words)
# Out:
# ['Natural', 'Language', 'Processing', ',', 'also', 'known', 'as', 'NLP', ',', 'is', 'one', 'of', 'the', 'most', 'important', 'areas', 'of', 'Artificial', 'Intelligence', '.', 'Today', ',', 'companies', 'use', 'NLP', 'in', 'chatbots', ',', 'search', 'engines', ',', 'recommendation', 'systems', ',', 'social', 'media', 'analytics', ',', 'customer', 'feedback', 'analysis', ',', 'automatic', 'translation', ',', 'and', 'voice', 'assistants', '.', 'In', '2026', ',', 'many', 'organizations', 'are', 'collecting', 'huge', 'amounts', 'of', 'text', 'data', 'from', 'websites', ',', 'emails', ',', 'reviews', ',', 'online', 'forms', ',', 'tweets', ',', 'product', 'comments', ',', 'and', 'support', 'tickets', '.', 'However', ',', 'this', 'text', 'data', 'is', 'often', 'messy', '.', 'For', 'example', ',', 'a', 'customer', 'may', 'write', ':', '``', 'I', 'LOVE', 'this', 'product', '!', '!', '!', 'Visit', 'https', ':', '//example.com/product123', '``', '.', 'Another', 'user', 'may', 'write', ':', '``', 'The', 'service', 'was', 'not', 'good', '...', 'I', 'waited', '45', 'minutes', 'and', 'no', 'one', 'replied', '.', "''", 'Before', 'applying', 'machine', 'learning', 'or', 'deep', 'learning', 'models', ',', 'we', 'need', 'to', 'clean', 'and', 'prepare', 'the', 'text', '.', 'This', 'step', 'is', 'called', 'text', 'preprocessing', '.', 'It', 'may', 'include', 'converting', 'text', 'to', 'lowercase', ',', 'removing', 'URLs', ',', 'removing', 'punctuation', ',', 'removing', 'numbers', ',', 'tokenizing', 'sentences', 'into', 'words', ',', 'removing', 'stop', 'words', ',', 'stemming', ',', 'lemmatization', ',', 'and', 'sometimes', 'removing', 'emojis', 'or', 'special', 'characters', '.', 'Good', 'preprocessing', 'can', 'improve', 'the', 'quality', 'of', 'NLP', 'models', '.', 'However', ',', 'preprocessing', 'should', 'be', 'done', 'carefully', '.', 'For', 'example', ',', 'removing', 'the', 'word', '``', 'not', "''", 'from', 'the', 'sentence', '``', 'I', 'am', 'not', 'happy', "''", 'can', 'change', 'the', 'meaning', 'completely', '.', 'Similarly', ',', 'removing', 'hashtags', 'may', 'not', 'always', 'be', 'a', 'good', 'idea', 'in', 'social', 'media', 'analytics', 'because', 'hashtags', 'can', 'contain', 'useful', 'information', 'about', 'topics', ',', 'opinions', ',', 'or', 'trends', '.', 'Your', 'task', 'is', 'to', 'build', 'a', 'complete', 'NLP', 'preprocessing', 'pipeline', 'for', 'this', 'text', '.', 'You', 'should', 'clean', 'the', 'text', 'step', 'by', 'step', 'and', 'observe', 'how', 'the', 'output', 'changes', 'after', 'each', 'step', '.']

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer,SnowballStemmer,LancasterStemmer
import spacy 

stemmer=PorterStemmer()
lemmitazer=WordNetLemmatizer()
snowball=SnowballStemmer("english")
lancaster=LancasterStemmer()
nlp = spacy.load("en_core_web_sm")


doc = nlp(rep_hash)


print("TOKEN".ljust(15),
      "LEMMA".ljust(15),
      "POS TAG")


print("-" * 40)


for token in doc:

    print(
       token.text.ljust(15),    
        token.lemma_.ljust(15),   
        token.pos_                
    )

snowballed=[snowball.stem(word) for word in words]
lancastered=[lancaster.stem(word) for word in words]
stemmed=[stemmer.stem(word) for word in words]
lemmitazed=[lemmitazer.lemmatize(word) for word in words]

print("here is snowballed words",snowballed)
print("here is lancastered words",lancastered)
print("here is stemmed words",stemmed)
print("here is lemmatized words",lemmitazed)
# Out:
# TOKEN           LEMMA           POS TAG
# ----------------------------------------
#
#
#                SPACE
# Natural         Natural         PROPN
# Language        Language        PROPN
# Processing      processing      NOUN
# ,               ,               PUNCT
# also            also            ADV
# known           know            VERB
# as              as              ADP
# NLP             NLP             PROPN
# ,               ,               PUNCT
# is              be              AUX
# one             one             NUM
# of              of              ADP
# the             the             DET
# most            most            ADV
# important       important       ADJ
# areas           area            NOUN
# of              of              ADP
# Artificial      Artificial      PROPN
# Intelligence    Intelligence    PROPN
# .               .               PUNCT
#
#
#                SPACE
# Today           today           NOUN
# ,               ,               PUNCT
# companies       company         NOUN
# use             use             VERB
# NLP             NLP             PROPN
# in              in              ADP
# chatbots        chatbot         NOUN
# ,               ,               PUNCT
# search          search          NOUN
# engines         engine          NOUN
# ,               ,               PUNCT
# recommendation  recommendation  NOUN
# systems         system          NOUN
# ,               ,               PUNCT
# social          social          ADJ
# media           medium          NOUN
# analytics       analytic        NOUN
# ,               ,               PUNCT
#
#
#                SPACE
# customer        customer        NOUN
# feedback        feedback        NOUN
# analysis        analysis        NOUN
# ,               ,               PUNCT
# automatic       automatic       ADJ
# translation     translation     NOUN
# ,               ,               PUNCT
# and             and             CCONJ
# voice           voice           NOUN
# assistants      assistant       NOUN
# .               .               PUNCT
#
#
#
#
#               SPACE
# In              in              ADP
# 2026            2026            NUM
# ,               ,               PUNCT
# many            many            ADJ
# organizations   organization    NOUN
# are             be              AUX
# collecting      collect         VERB
# huge            huge            ADJ
# amounts         amount          NOUN
# of              of              ADP
# text            text            NOUN
# data            datum           NOUN
# from            from            ADP
# websites        website         NOUN
# ,               ,               PUNCT
# emails          email           NOUN
# ,               ,               PUNCT
# reviews         review          NOUN
# ,               ,               PUNCT
#
#
#                SPACE
# online          online          ADJ
# forms           form            NOUN
# ,               ,               PUNCT
# tweets          tweet           NOUN
# ,               ,               PUNCT
# product         product         NOUN
# comments        comment         NOUN
# ,               ,               PUNCT
# and             and             CCONJ
# support         support         NOUN
# tickets         ticket          NOUN
# .               .               PUNCT
# However         however         ADV
# ,               ,               PUNCT
# this            this            DET
# text            text            NOUN
# data            data            NOUN
# is              be              AUX
# often           often           ADV
# messy           messy           ADJ
# .               .               PUNCT
#
#
#                SPACE
# For             for             ADP
# example         example         NOUN
# ,               ,               PUNCT
# a               a               DET
# customer        customer        NOUN
# may             may             AUX
# write           write           VERB
# :               :               PUNCT
# "               "               PUNCT
# I               I               PRON
# LOVE            love            VERB
# this            this            DET
# product         product         NOUN
# !               !               PUNCT
# !               !               PUNCT
# !               !               PUNCT
# Visit           visit           VERB
# https://example.com/product123 https://example.com/product123 PRON
#                                 SPACE
# "               "               PUNCT
# .               .               PUNCT
#
#
#                SPACE
# Another         another         DET
# user            user            NOUN
# may             may             AUX
# write           write           VERB
# :               :               PUNCT
# "               "               PUNCT
# The             the             DET
# service         service         NOUN
# was             be              AUX
# not             not             PART
# good            good            ADJ
# ...             ...             PUNCT
# I               I               PRON
# waited          wait            VERB
# 45              45              NUM
# minutes         minute          NOUN
# and             and             CCONJ
# no              no              DET
# one             one             NOUN
# replied         reply           VERB
# .               .               PUNCT
# "               "               PUNCT
#
#
#
#
#               SPACE
# Before          before          ADP
# applying        apply           VERB
# machine         machine         NOUN
# learning        learning        NOUN
# or              or              CCONJ
# deep            deep            ADJ
# learning        learning        NOUN
# models          model           NOUN
# ,               ,               PUNCT
# we              we              PRON
# need            need            VERB
# to              to              PART
# clean           clean           VERB
# and             and             CCONJ
# prepare         prepare         VERB
# the             the             DET
# text            text            NOUN
# .               .               PUNCT
#
#
#                SPACE
# This            this            DET
# step            step            NOUN
# is              be              AUX
# called          call            VERB
# text            text            NOUN
# preprocessing   preprocessing   NOUN
# .               .               PUNCT
# It              it              PRON
# may             may             AUX
# include         include         VERB
# converting      convert         VERB
# text            text            NOUN
# to              to              PART
# lowercase       lowercase       VERB
# ,               ,               PUNCT
# removing        remove          VERB
# URLs            url             NOUN
# ,               ,               PUNCT
#
#
#                SPACE
# removing        remove          VERB
# punctuation     punctuation     NOUN
# ,               ,               PUNCT
# removing        remove          VERB
# numbers         number          NOUN
# ,               ,               PUNCT
# tokenizing      tokenize        VERB
# sentences       sentence        NOUN
# into            into            ADP
# words           word            NOUN
# ,               ,               PUNCT
# removing        remove          VERB
# stop            stop            NOUN
# words           word            NOUN
# ,               ,               PUNCT
#
#
#                SPACE
# stemming        stemming        NOUN
# ,               ,               PUNCT
# lemmatization   lemmatization   NOUN
# ,               ,               PUNCT
# and             and             CCONJ
# sometimes       sometimes       ADV
# removing        remove          VERB
# emojis          emoji           NOUN
# or              or              CCONJ
# special         special         ADJ
# characters      character       NOUN
# .               .               PUNCT
#
#
#
#
#               SPACE
# Good            good            ADJ
# preprocessing   preprocessing   NOUN
# can             can             AUX
# improve         improve         VERB
# the             the             DET
# quality         quality         NOUN
# of              of              ADP
# NLP             NLP             PROPN
# models          model           NOUN
# .               .               PUNCT
# However         however         ADV
# ,               ,               PUNCT
# preprocessing   preprocessing   NOUN
# should          should          AUX
# be              be              AUX
# done            do              VERB
# carefully       carefully       ADV
# .               .               PUNCT
#
#
#                SPACE
# For             for             ADP
# example         example         NOUN
# ,               ,               PUNCT
# removing        remove          VERB
# the             the             DET
# word            word            NOUN
# "               "               PUNCT
# not             not             PART
# "               "               PUNCT
# from            from            ADP
# the             the             DET
# sentence        sentence        NOUN
# "               "               PUNCT
# I               I               PRON
# am              be              AUX
# not             not             PART
# happy           happy           ADJ
# "               "               PUNCT
# can             can             AUX
# change          change          VERB
# the             the             DET
# meaning         meaning         NOUN
# completely      completely      ADV
# .               .               PUNCT
#
#
#                SPACE
# Similarly       similarly       ADV
# ,               ,               PUNCT
# removing        remove          VERB
# hashtags        hashtag         NOUN
# may             may             AUX
# not             not             PART
# always          always          ADV
# be              be              AUX
# a               a               DET
# good            good            ADJ
# idea            idea            NOUN
# in              in              ADP
# social          social          ADJ
# media           medium          NOUN
# analytics       analytic        NOUN
# because         because         SCONJ
# hashtags        hashtag         NOUN
#
#
#                SPACE
# can             can             AUX
# contain         contain         VERB
# useful          useful          ADJ
# information     information     NOUN
# about           about           ADP
# topics          topic           NOUN
# ,               ,               PUNCT
# opinions        opinion         NOUN
# ,               ,               PUNCT
# or              or              CCONJ
# trends          trend           NOUN
# .               .               PUNCT
#
#
#
#
#               SPACE
# Your            your            PRON
# task            task            NOUN
# is              be              AUX
# to              to              PART
# build           build           VERB
# a               a               DET
# complete        complete        ADJ
# NLP             NLP             PROPN
# preprocessing   preprocesse     VERB
# pipeline        pipeline        NOUN
# for             for             ADP
# this            this            DET
# text            text            NOUN
# .               .               PUNCT
#
#
#                SPACE
# You             you             PRON
# should          should          AUX
# clean           clean           VERB
# the             the             DET
# text            text            NOUN
# step            step            NOUN
# by              by              ADP
# step            step            NOUN
# and             and             CCONJ
# observe         observe         VERB
# how             how             SCONJ
# the             the             DET
# output          output          NOUN
# changes         change          VERB
# after           after           ADP
# each            each            DET
# step            step            NOUN
# .               .               PUNCT
#
#
#                SPACE
# here is snowballed words ['natur', 'languag', 'process', ',', 'also', 'known', 'as', 'nlp', ',', 'is', 'one', 'of', 'the', 'most', 'import', 'area', 'of', 'artifici', 'intellig', '.', 'today', ',', 'compani', 'use', 'nlp', 'in', 'chatbot', ',', 'search', 'engin', ',', 'recommend', 'system', ',', 'social', 'media', 'analyt', ',', 'custom', 'feedback', 'analysi', ',', 'automat', 'translat', ',', 'and', 'voic', 'assist', '.', 'in', '2026', ',', 'mani', 'organ', 'are', 'collect', 'huge', 'amount', 'of', 'text', 'data', 'from', 'websit', ',', 'email', ',', 'review', ',', 'onlin', 'form', ',', 'tweet', ',', 'product', 'comment', ',', 'and', 'support', 'ticket', '.', 'howev', ',', 'this', 'text', 'data', 'is', 'often', 'messi', '.', 'for', 'exampl', ',', 'a', 'custom', 'may', 'write', ':', '``', 'i', 'love', 'this', 'product', '!', '!', '!', 'visit', 'https', ':', '//example.com/product123', '``', '.', 'anoth', 'user', 'may', 'write', ':', '``', 'the', 'servic', 'was', 'not', 'good', '...', 'i', 'wait', '45', 'minut', 'and', 'no', 'one', 'repli', '.', "''", 'befor', 'appli', 'machin', 'learn', 'or', 'deep', 'learn', 'model', ',', 'we', 'need', 'to', 'clean', 'and', 'prepar', 'the', 'text', '.', 'this', 'step', 'is', 'call', 'text', 'preprocess', '.', 'it', 'may', 'includ', 'convert', 'text', 'to', 'lowercas', ',', 'remov', 'url', ',', 'remov', 'punctuat', ',', 'remov', 'number', ',', 'token', 'sentenc', 'into', 'word', ',', 'remov', 'stop', 'word', ',', 'stem', ',', 'lemmat', ',', 'and', 'sometim', 'remov', 'emoji', 'or', 'special', 'charact', '.', 'good', 'preprocess', 'can', 'improv', 'the', 'qualiti', 'of', 'nlp', 'model', '.', 'howev', ',', 'preprocess', 'should', 'be', 'done', 'care', '.', 'for', 'exampl', ',', 'remov', 'the', 'word', '``', 'not', "''", 'from', 'the', 'sentenc', '``', 'i', 'am', 'not', 'happi', "''", 'can', 'chang', 'the', 'mean', 'complet', '.', 'similar', ',', 'remov', 'hashtag', 'may', 'not', 'alway', 'be', 'a', 'good', 'idea', 'in', 'social', 'media', 'analyt', 'becaus', 'hashtag', 'can', 'contain', 'use', 'inform', 'about', 'topic', ',', 'opinion', ',', 'or', 'trend', '.', 'your', 'task', 'is', 'to', 'build', 'a', 'complet', 'nlp', 'preprocess', 'pipelin', 'for', 'this', 'text', '.', 'you', 'should', 'clean', 'the', 'text', 'step', 'by', 'step', 'and', 'observ', 'how', 'the', 'output', 'chang', 'after', 'each', 'step', '.']
# here is lancastered words ['nat', 'langu', 'process', ',', 'also', 'known', 'as', 'nlp', ',', 'is', 'on', 'of', 'the', 'most', 'import', 'area', 'of', 'art', 'intellig', '.', 'today', ',', 'company', 'us', 'nlp', 'in', 'chatbot', ',', 'search', 'engin', ',', 'recommend', 'system', ',', 'soc', 'med', 'analys', ',', 'custom', 'feedback', 'analys', ',', 'autom', 'transl', ',', 'and', 'voic', 'assist', '.', 'in', '2026', ',', 'many', 'org', 'ar', 'collect', 'hug', 'amount', 'of', 'text', 'dat', 'from', 'websit', ',', 'email', ',', 'review', ',', 'onlin', 'form', ',', 'tweet', ',', 'produc', 'com', ',', 'and', 'support', 'ticket', '.', 'howev', ',', 'thi', 'text', 'dat', 'is', 'oft', 'messy', '.', 'for', 'exampl', ',', 'a', 'custom', 'may', 'writ', ':', '``', 'i', 'lov', 'thi', 'produc', '!', '!', '!', 'visit', 'https', ':', '//example.com/product123', '``', '.', 'anoth', 'us', 'may', 'writ', ':', '``', 'the', 'serv', 'was', 'not', 'good', '...', 'i', 'wait', '45', 'minut', 'and', 'no', 'on', 'reply', '.', "''", 'bef', 'apply', 'machin', 'learn', 'or', 'deep', 'learn', 'model', ',', 'we', 'nee', 'to', 'cle', 'and', 'prep', 'the', 'text', '.', 'thi', 'step', 'is', 'cal', 'text', 'preprocess', '.', 'it', 'may', 'includ', 'convert', 'text', 'to', 'lowercas', ',', 'remov', 'url', ',', 'remov', 'punctu', ',', 'remov', 'numb', ',', 'tok', 'sent', 'into', 'word', ',', 'remov', 'stop', 'word', ',', 'stem', ',', 'lem', ',', 'and', 'sometim', 'remov', 'emod', 'or', 'spec', 'charact', '.', 'good', 'preprocess', 'can', 'improv', 'the', 'qual', 'of', 'nlp', 'model', '.', 'howev', ',', 'preprocess', 'should', 'be', 'don', 'car', '.', 'for', 'exampl', ',', 'remov', 'the', 'word', '``', 'not', "''", 'from', 'the', 'sent', '``', 'i', 'am', 'not', 'happy', "''", 'can', 'chang', 'the', 'mean', 'complet', '.', 'simil', ',', 'remov', 'hasht', 'may', 'not', 'alway', 'be', 'a', 'good', 'ide', 'in', 'soc', 'med', 'analys', 'becaus', 'hasht', 'can', 'contain', 'us', 'inform', 'about', 'top', ',', 'opin', ',', 'or', 'trend', '.', 'yo', 'task', 'is', 'to', 'build', 'a', 'complet', 'nlp', 'preprocess', 'pipelin', 'for', 'thi', 'text', '.', 'you', 'should', 'cle', 'the', 'text', 'step', 'by', 'step', 'and', 'observ', 'how', 'the', 'output', 'chang', 'aft', 'each', 'step', '.']
# here is stemmed words ['natur', 'languag', 'process', ',', 'also', 'known', 'as', 'nlp', ',', 'is', 'one', 'of', 'the', 'most', 'import', 'area', 'of', 'artifici', 'intellig', '.', 'today', ',', 'compani', 'use', 'nlp', 'in', 'chatbot', ',', 'search', 'engin', ',', 'recommend', 'system', ',', 'social', 'media', 'analyt', ',', 'custom', 'feedback', 'analysi', ',', 'automat', 'translat', ',', 'and', 'voic', 'assist', '.', 'in', '2026', ',', 'mani', 'organ', 'are', 'collect', 'huge', 'amount', 'of', 'text', 'data', 'from', 'websit', ',', 'email', ',', 'review', ',', 'onlin', 'form', ',', 'tweet', ',', 'product', 'comment', ',', 'and', 'support', 'ticket', '.', 'howev', ',', 'thi', 'text', 'data', 'is', 'often', 'messi', '.', 'for', 'exampl', ',', 'a', 'custom', 'may', 'write', ':', '``', 'i', 'love', 'thi', 'product', '!', '!', '!', 'visit', 'http', ':', '//example.com/product123', '``', '.', 'anoth', 'user', 'may', 'write', ':', '``', 'the', 'servic', 'wa', 'not', 'good', '...', 'i', 'wait', '45', 'minut', 'and', 'no', 'one', 'repli', '.', "''", 'befor', 'appli', 'machin', 'learn', 'or', 'deep', 'learn', 'model', ',', 'we', 'need', 'to', 'clean', 'and', 'prepar', 'the', 'text', '.', 'thi', 'step', 'is', 'call', 'text', 'preprocess', '.', 'it', 'may', 'includ', 'convert', 'text', 'to', 'lowercas', ',', 'remov', 'url', ',', 'remov', 'punctuat', ',', 'remov', 'number', ',', 'token', 'sentenc', 'into', 'word', ',', 'remov', 'stop', 'word', ',', 'stem', ',', 'lemmat', ',', 'and', 'sometim', 'remov', 'emoji', 'or', 'special', 'charact', '.', 'good', 'preprocess', 'can', 'improv', 'the', 'qualiti', 'of', 'nlp', 'model', '.', 'howev', ',', 'preprocess', 'should', 'be', 'done', 'care', '.', 'for', 'exampl', ',', 'remov', 'the', 'word', '``', 'not', "''", 'from', 'the', 'sentenc', '``', 'i', 'am', 'not', 'happi', "''", 'can', 'chang', 'the', 'mean', 'complet', '.', 'similarli', ',', 'remov', 'hashtag', 'may', 'not', 'alway', 'be', 'a', 'good', 'idea', 'in', 'social', 'media', 'analyt', 'becaus', 'hashtag', 'can', 'contain', 'use', 'inform', 'about', 'topic', ',', 'opinion', ',', 'or', 'trend', '.', 'your', 'task', 'is', 'to', 'build', 'a', 'complet', 'nlp', 'preprocess', 'pipelin', 'for', 'thi', 'text', '.', 'you', 'should', 'clean', 'the', 'text', 'step', 'by', 'step', 'and', 'observ', 'how', 'the', 'output', 'chang', 'after', 'each', 'step', '.']
# here is lemmatized words ['Natural', 'Language', 'Processing', ',', 'also', 'known', 'a', 'NLP', ',', 'is', 'one', 'of', 'the', 'most', 'important', 'area', 'of', 'Artificial', 'Intelligence', '.', 'Today', ',', 'company', 'use', 'NLP', 'in', 'chatbots', ',', 'search', 'engine', ',', 'recommendation', 'system', ',', 'social', 'medium', 'analytics', ',', 'customer', 'feedback', 'analysis', ',', 'automatic', 'translation', ',', 'and', 'voice', 'assistant', '.', 'In', '2026', ',', 'many', 'organization', 'are', 'collecting', 'huge', 'amount', 'of', 'text', 'data', 'from', 'website', ',', 'email', ',', 'review', ',', 'online', 'form', ',', 'tweet', ',', 'product', 'comment', ',', 'and', 'support', 'ticket', '.', 'However', ',', 'this', 'text', 'data', 'is', 'often', 'messy', '.', 'For', 'example', ',', 'a', 'customer', 'may', 'write', ':', '``', 'I', 'LOVE', 'this', 'product', '!', '!', '!', 'Visit', 'http', ':', '//example.com/product123', '``', '.', 'Another', 'user', 'may', 'write', ':', '``', 'The', 'service', 'wa', 'not', 'good', '...', 'I', 'waited', '45', 'minute', 'and', 'no', 'one', 'replied', '.', "''", 'Before', 'applying', 'machine', 'learning', 'or', 'deep', 'learning', 'model', ',', 'we', 'need', 'to', 'clean', 'and', 'prepare', 'the', 'text', '.', 'This', 'step', 'is', 'called', 'text', 'preprocessing', '.', 'It', 'may', 'include', 'converting', 'text', 'to', 'lowercase', ',', 'removing', 'URLs', ',', 'removing', 'punctuation', ',', 'removing', 'number', ',', 'tokenizing', 'sentence', 'into', 'word', ',', 'removing', 'stop', 'word', ',', 'stemming', ',', 'lemmatization', ',', 'and', 'sometimes', 'removing', 'emojis', 'or', 'special', 'character', '.', 'Good', 'preprocessing', 'can', 'improve', 'the', 'quality', 'of', 'NLP', 'model', '.', 'However', ',', 'preprocessing', 'should', 'be', 'done', 'carefully', '.', 'For', 'example', ',', 'removing', 'the', 'word', '``', 'not', "''", 'from', 'the', 'sentence', '``', 'I', 'am', 'not', 'happy', "''", 'can', 'change', 'the', 'meaning', 'completely', '.', 'Similarly', ',', 'removing', 'hashtags', 'may', 'not', 'always', 'be', 'a', 'good', 'idea', 'in', 'social', 'medium', 'analytics', 'because', 'hashtags', 'can', 'contain', 'useful', 'information', 'about', 'topic', ',', 'opinion', ',', 'or', 'trend', '.', 'Your', 'task', 'is', 'to', 'build', 'a', 'complete', 'NLP', 'preprocessing', 'pipeline', 'for', 'this', 'text', '.', 'You', 'should', 'clean', 'the', 'text', 'step', 'by', 'step', 'and', 'observe', 'how', 'the', 'output', 'change', 'after', 'each', 'step', '.']

# %%
#removing punctuations
punkt=string.punctuation
clean_text=[word for word in lemmitazed if word not in punkt]
print(clean_text)
# Out:
# ['Natural', 'Language', 'Processing', 'also', 'known', 'a', 'NLP', 'is', 'one', 'of', 'the', 'most', 'important', 'area', 'of', 'Artificial', 'Intelligence', 'Today', 'company', 'use', 'NLP', 'in', 'chatbots', 'search', 'engine', 'recommendation', 'system', 'social', 'medium', 'analytics', 'customer', 'feedback', 'analysis', 'automatic', 'translation', 'and', 'voice', 'assistant', 'In', '2026', 'many', 'organization', 'are', 'collecting', 'huge', 'amount', 'of', 'text', 'data', 'from', 'website', 'email', 'review', 'online', 'form', 'tweet', 'product', 'comment', 'and', 'support', 'ticket', 'However', 'this', 'text', 'data', 'is', 'often', 'messy', 'For', 'example', 'a', 'customer', 'may', 'write', '``', 'I', 'LOVE', 'this', 'product', 'Visit', 'http', '//example.com/product123', '``', 'Another', 'user', 'may', 'write', '``', 'The', 'service', 'wa', 'not', 'good', '...', 'I', 'waited', '45', 'minute', 'and', 'no', 'one', 'replied', "''", 'Before', 'applying', 'machine', 'learning', 'or', 'deep', 'learning', 'model', 'we', 'need', 'to', 'clean', 'and', 'prepare', 'the', 'text', 'This', 'step', 'is', 'called', 'text', 'preprocessing', 'It', 'may', 'include', 'converting', 'text', 'to', 'lowercase', 'removing', 'URLs', 'removing', 'punctuation', 'removing', 'number', 'tokenizing', 'sentence', 'into', 'word', 'removing', 'stop', 'word', 'stemming', 'lemmatization', 'and', 'sometimes', 'removing', 'emojis', 'or', 'special', 'character', 'Good', 'preprocessing', 'can', 'improve', 'the', 'quality', 'of', 'NLP', 'model', 'However', 'preprocessing', 'should', 'be', 'done', 'carefully', 'For', 'example', 'removing', 'the', 'word', '``', 'not', "''", 'from', 'the', 'sentence', '``', 'I', 'am', 'not', 'happy', "''", 'can', 'change', 'the', 'meaning', 'completely', 'Similarly', 'removing', 'hashtags', 'may', 'not', 'always', 'be', 'a', 'good', 'idea', 'in', 'social', 'medium', 'analytics', 'because', 'hashtags', 'can', 'contain', 'useful', 'information', 'about', 'topic', 'opinion', 'or', 'trend', 'Your', 'task', 'is', 'to', 'build', 'a', 'complete', 'NLP', 'preprocessing', 'pipeline', 'for', 'this', 'text', 'You', 'should', 'clean', 'the', 'text', 'step', 'by', 'step', 'and', 'observe', 'how', 'the', 'output', 'change', 'after', 'each', 'step']
