# %%
import spacy

# %%
nlp=spacy.load("en_core_web_sm")

# %%
text="A spaCy pipeline for tokenization."
doc=nlp(text)

# %%
print([token.text for token in doc])
# Out:
# ['A', 'spaCy', 'pipeline', 'for', 'tokenization', '.']
