# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import root_mean_squared_error

# %%
df=pd.read_csv('diabetes_clean.csv')

# %%
X=df[['pregnancies','glucose','diastolic','triceps','insulin','bmi','dpf','age']].values
y=df['diabetes'].values
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42,stratify=y)

# %%
print(df['diabetes'].value_counts())
reg=LinearRegression()
reg.fit(X_train,y_train)
print(X_test.shape, y_test.shape)
# Out:
# diabetes
# 0    500
# 1    268
# Name: count, dtype: int64
# (231, 8) (231,)

# %%
a=reg.predict(X_test)
print("Predictions: {}, Actual Values: {}".format(a[:2], y_test[:2]))
print(reg.score(X_test,y_test))
print(root_mean_squared_error(y_test,a))
# Out:
# Predictions: [0.29955441 0.35353347], Actual Values: [1 1]
# 0.2892946474120145
# 0.4022730629001421
