# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
df=pd.read_csv('stackoverflow_200.csv')

# %%
df.head()
# Out:
#    user_id  ...                                           top_tags
# 0  1868625  ...  datetime:43332(10223), c++:198658(30000), text...
# 1  9143400  ...  .net:76079(7526), eclipse:61844(12836), python...
# 2   729777  ...  azure:301018(30000), tidyverse:311093(30000), ...
# 3  6121668  ...  awk:153882(24982), winforms:81617(7157), fasta...
# 4   939283  ...  perl:139276(17422), indexing:69432(6267), asp....
#
# [5 rows x 10 columns]
